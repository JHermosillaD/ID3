# %% [markdown]
# # Iterative Dichotomiser 3 (ID3)

# %% [markdown]
# ## Summary:
#
# - [x] Implementation of the original ID3 algorithm
# - [x] Performance analysis using k-fold Cross-Validation
# - [x] Comparison of accuracy vs. dataset size

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Libraries and auxiliary functions

# %%
from IPython.display import Image, display
import pandas as pd
import numpy as np
import pydot
import os

cwd = os.getcwd()
data_path = f'{cwd}/data/'

# %%
class Tree_printer:
    def __init__(self, tree):    
        self.tree = tree
        self.graph = pydot.Dot(graph_type='digraph', strict=True)
        
    def draw(self, parent_name, child_name):
        edge = pydot.Edge(parent_name, child_name)
        self.graph.add_edge(edge)
            
    def visit(self, node, parent=None):
        for k,v in node.items():
            if isinstance(v, dict):
                if parent:
                    self.draw(parent, k)
                self.visit(v, k)
            else:
                self.draw(parent, k)
                self.draw(k, k+'_'+v)

    def view_pydot(self):
        self.visit(self.tree)
        plt = Image(self.graph.create_png())
        display(plt)

# %% [markdown]
# ### Main

# %%
class ID3_class:
    def __init__(self, dataset):
        self.df = dataset
        self.class_label = self.df.keys()[-1]
        self.class_values = self.df[self.class_label].unique()

    '''Total entropy H(T) '''
    def Total_entropy(self, df):
        entropy = 0
        for value in self.class_values:
            entropy += -df[self.class_label].value_counts()[value]/len(df[self.class_label])*np.log2(df[self.class_label].value_counts()[value]/len(df[self.class_label]))
        return entropy

    '''Conditional entropy per attribute-value H(T|a=v)'''
    def Conditional_entropy(self, df, attribute, attribute_value):
        entropy = 0
        eps = np.finfo(float).eps
        for i_class in self.class_values:
            num = len(df[attribute][df[attribute]==attribute_value][df[self.class_label] ==i_class])
            den = len(df[attribute][df[attribute]==attribute_value])
            entropy += -num/(den+eps)*np.log2(num/(den+eps)+eps)
        return entropy

    '''Information gain per attribute I(a) = H(T) - Sum P(a)H(T|a=v)'''
    def Information_gain(self, df, attribute):
        attributes = df[attribute].unique()    
        information_gain = self.Total_entropy(df)
        for attribute_value in attributes:
            entropy = self.Conditional_entropy(df, attribute, attribute_value)
            probability = len(df[attribute][df[attribute]==attribute_value])/len(df)
            information_gain += -probability*entropy
        return information_gain

    '''Attribute with highest information gain I(a)'''
    def Best_attribute(self, df):
        gains = []
        for attribute in df.keys()[:-1]:
            gains.append(self.Information_gain(df,attribute))
        return df.keys()[:-1][np.argmax(gains)]

    '''Create tree'''
    def Create_tree(self, df=None, tree=None):
        attribute = self.Best_attribute(df)    
        attribute_values = np.unique(df[attribute])
        if tree is None: 
            tree={}
            tree[attribute] = {}
        for value in attribute_values:
            subtable = df[df[attribute] == value].reset_index(drop=True)
            clValue, counts = np.unique(subtable[self.class_label],return_counts=True)                        
            if len(counts)==1:
                tree[attribute][value] = clValue[0]         
            else:        
                tree[attribute][value] = self.Create_tree(subtable)  
        return tree

    '''Predict class from instance'''
    def Predict(self, tree, instance):
        if not isinstance(tree, dict): 
            return tree 
        else:
            root_node = next(iter(tree)) 
            feature_value = instance[root_node] 
            if feature_value in tree[root_node]: 
                return self.Predict(tree[root_node][feature_value], instance) 
            else:
                return None
            
    '''Estimate average accuracy'''
    def Evaluate(self, tree, df_test):
        correct_preditct = 0
        wrong_preditct = 0
        for index, row in df_test.iterrows():
            result = self.Predict(tree, df_test.iloc[index]) 
            if result == df_test[self.class_label].iloc[index]:
                correct_preditct += 1 
            else:
                wrong_preditct += 1
        accuracy = correct_preditct / (correct_preditct + wrong_preditct) 
        return accuracy

# %% [markdown]
# ## Datasets

# %% [markdown]
# #### D1 Play Tennis

# %%
D1_path = '/D4_mushroom/agaricus-lepiota.csv'
df_test = pd.read_csv("/home/jhermosilla/Documents/GitHub/ID3/data/test/Test_PlayTennis.csv") 
D1_train = pd.read_csv(data_path + D1_path) 
D1_train.drop(['stalk-root'], axis=1)
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            p           x         s       n    t               p
# 1            e           x         s       y    t               a
# 2            e           b         s       w    t               l
# 3            p           x         y       w    t               p
# 4            e           x         s       g    f               n
# ...        ...         ...       ...     ...  ...             ...
# 8119         e           k         s       n    f               n
# 8120         e           x         s       n    f               n
# 8121         e           f         s       n    f               n
# 8122         p           k         y       n    f               y
# 8123         e           x         s       n    f               n
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               f         c          n           k  ...
# 1               f         c          b           k  ...
# 2               f         c          b           n  ...
# 3               f         c          n           n  ...
# 4               f         w          b           k  ...
# ...           ...       ...        ...         ...  ...
# 8119            a         c          b           y  ...
# 8120            a         c          b           y  ...
# 8121            a         c          b           n  ...
# 8122            f         c          n           b  ...
# 8123            a         c          b           y  ...
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         s                      w         w          p
# 1                         s                      w         w          p
# 2                         s                      w         w          p
# 3                         s                      w         w          p
# 4                         s                      w         w          p
# ...                     ...                    ...       ...        ...
# 8119                      s                      o         o          p
# 8120                      s                      o         o          p
# 8121                      s                      o         o          p
# 8122                      k                      w         w          p
# 8123                      s                      o         o          p
#
#      ring-number ring-type spore-print-color population habitat specie
# 0              w         o                 p          k       s      u
# 1              w         o                 p          n       n      g
# 2              w         o                 p          n       n      m
# 3              w         o                 p          k       s      u
# 4              w         o                 e          n       a      g
# ...          ...       ...               ...        ...     ...    ...
# 8119           o         o                 p          b       c      l
# 8120           n         o                 p          b       v      l
# 8121           o         o                 p          b       c      l
# 8122           w         o                 e          w       v      l
# 8123           o         o                 p          o       c      l
#
# [8124 rows x 22 columns]

# %%
df_test.head(4)
# Out:
#     Outlook Temperature Humidity    Wind Play Tennis
# 0  Overcast        Mild   Normal    Weak         Yes
# 1     Sunny        Mild   Normal    Weak         Yes
# 2      Rain        Mild   Normal    Weak         Yes
# 3      Rain        Cool     High  Strong          No

# %%
D1_train.head(4)
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         p           x         s       n    t               p            f
# 1         e           x         s       y    t               a            f
# 2         e           b         s       w    t               l            f
# 3         p           x         y       w    t               p            f
#
#   gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0         c          n           k  ...                      s
# 1         c          b           k  ...                      s
# 2         c          b           n  ...                      s
# 3         c          n           n  ...                      s
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         w          p           w         o
# 1                      w         w          p           w         o
# 2                      w         w          p           w         o
# 3                      w         w          p           w         o
#
#   spore-print-color population habitat specie
# 0                 p          k       s      u
# 1                 p          n       n      g
# 2                 p          n       n      m
# 3                 p          k       s      u
#
# [4 rows x 23 columns]

# %%
D1 = ID3_class(D1_train)

# %%
D1.Total_entropy(D1_train)
# Out:
# 2.274747200596189

# %%
D1_tree = D1.Create_tree(D1_train)
#D1_accuracy = D1.Evaluate(D1_tree, df_test)
D1_display = Tree_printer(D1_tree)
D1_display.view_pydot()
#print(D1_accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'u'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 D1_tree = D1.Create_tree(D1_train)
#       2 #D1_accuracy = D1.Evaluate(D1_tree, df_test)
#       3 D1_display = Tree_printer(D1_tree)
#
# Cell In[21], line 54, in ID3_class.Create_tree(self, df, tree)
#      52         tree[attribute][value] = clValue[0]
#      53     else:
# ---> 54         tree[attribute][value] = self.Create_tree(subtable)
#      55 return tree
#
# Cell In[21], line 43, in ID3_class.Create_tree(self, df, tree)
#      42 def Create_tree(self, df=None, tree=None):
# ---> 43     attribute = self.Best_attribute(df)
#      44     attribute_values = np.unique(df[attribute])
#      45     if tree is None:
#
# Cell In[21], line 38, in ID3_class.Best_attribute(self, df)
#      36 gains = []
#      37 for attribute in df.keys()[:-1]:
# ---> 38     gains.append(self.Information_gain(df,attribute))
#      39 return df.keys()[:-1][np.argmax(gains)]
#
# Cell In[21], line 27, in ID3_class.Information_gain(self, df, attribute)
#      25 def Information_gain(self, df, attribute):
#      26     attributes = df[attribute].unique()
# ---> 27     information_gain = self.Total_entropy(df)
#      28     for attribute_value in attributes:
#      29         entropy = self.Conditional_entropy(df, attribute, attribute_value)
#
# Cell In[21], line 11, in ID3_class.Total_entropy(self, df)
#       9 entropy = 0
#      10 for value in self.class_values:
# ---> 11     entropy += -df[self.class_label].value_counts()[value]/len(df[self.class_label])*np.log2(df[self.class_label].value_counts()[value]/len(df[self.class_label]))
#      12 return entropy
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'u'
